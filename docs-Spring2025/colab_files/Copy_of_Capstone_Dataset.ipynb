# %% [markdown]
# # Data Analytics Process :
#
# This is an amalgamation of the datasets that were successfully scraped from BrightData.com.
# Within this notebook, I combine all of the data that had been gathered (approximately 3000 or so
# records) and create a dataset that can be more easily traversed, and holds only the information
# relevant to our project (primarily the title, location, type, and description of the listing). In
# addition, I also include a few visuals to illustrate just a few of the trends / correlations that
# may be relevant within our scope of the project.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load in CSVs:
linkedin_df = pd.read_csv('Linkedin job listings information.csv')
indeed_df = pd.read_csv('Indeed job listings information.csv')
glassdoor_df = pd.read_csv('Glassdoor job listings information.csv')

# Confirm successful loading of sets
print("LinkedIn Data:")
print(linkedin_df.head())

print("\nIndeed Data:")
print(indeed_df.head())

print("\nGlassDoor Data:")
print(glassdoor_df.head())
# Out:
# LinkedIn Data:
#                                                  url  job_posting_id  \
# 0  https://www.linkedin.com/jobs/view/4129831164/...      4129831164
# 1  https://www.linkedin.com/jobs/view/4121271428/...      4121271428
# 2  https://www.linkedin.com/jobs/view/4128604654/...      4128604654
# 3  https://www.linkedin.com/jobs/view/4127880523/...      4127880523
# 4  https://www.linkedin.com/jobs/view/4049869381/...      4049869381
#
#                                  job_title  \
# 0  Software Developer - Driver and Vehicle
# 1                            API Developer
# 2                           .Net Developer
# 3                         Power BI Analyst
# 4        Scala Software Engineer - Backend
#
#                           company_name  company_id              job_location  \
# 0  Canadian Bank Note Company, Limited      718150   Ottawa, Ontario, Canada
# 1                          Venngo Inc.      126508  Toronto, Ontario, Canada
# 2                            BLAZESOFT     9188224  Vaughan, Ontario, Canada
# 3          Alquemy Search & Consulting     3078066  Calgary, Alberta, Canada
# 4                               Avetta     7584447                    Canada
#
#                                          job_summary job_seniority_level  \
# 0  Description Internal Job Title : Software Deve...         Entry level
# 1  Who we are At Venngo, we provide premium disco...           Associate
# 2  Join our dynamic and innovative gaming company...    Mid-Senior level
# 3  Power BI Analyst 12 month contract, potential ...    Mid-Senior level
# 4  Avetta is Hiring a Scala Software Engineer - B...    Mid-Senior level
#
#                              job_function job_employment_type  ...  \
# 0  Engineering and Information Technology           Full-time  ...
# 1  Engineering and Information Technology           Full-time  ...
# 2                                   Other           Full-time  ...
# 3                  Information Technology            Contract  ...
# 4  Engineering and Information Technology           Full-time  ...
#
#                                      discovery_input  \
# 0  {"experience_level":null,"job_type":null,"remo...
# 1  {"experience_level":null,"job_type":null,"remo...
# 2  {"experience_level":null,"job_type":null,"remo...
# 3  {"experience_level":null,"job_type":null,"remo...
# 4  {"experience_level":null,"job_type":null,"remo...
#
#                                           apply_link country_code title_id  \
# 0  https://www.linkedin.com/jobs/view/externalApp...          NaN      9.0
# 1  https://www.linkedin.com/jobs/view/externalApp...          NaN      9.0
# 2  https://www.linkedin.com/jobs/view/externalApp...          NaN   4384.0
# 3                                                NaN          NaN   2336.0
# 4  https://www.linkedin.com/jobs/view/externalApp...          NaN      9.0
#
#                                         company_logo  \
# 0  "https://media.licdn.com/dms/image/v2/C560BAQG...
# 1  "https://media.licdn.com/dms/image/v2/C4D0BAQG...
# 2  "https://media.licdn.com/dms/image/v2/D560BAQH...
# 3  "https://media.licdn.com/dms/image/v2/D560BAQG...
# 4  "https://media.licdn.com/dms/image/v2/D560BAQH...
#
#               job_posted_date  \
# 0  "2025-01-22T05:23:25.270Z"
# 1  "2025-01-17T16:23:26.269Z"
# 2  "2025-01-18T16:24:35.693Z"
# 3  "2025-01-18T17:20:33.585Z"
# 4  "2025-01-16T16:39:25.906Z"
#
#                                           job_poster application_availability  \
# 0              {"name":null,"title":null,"url":null}                     True
# 1              {"name":null,"title":null,"url":null}                     True
# 2              {"name":null,"title":null,"url":null}                     True
# 3  {"name":"Mat███unr███","title":"Sr. I.T. Recru...                     True
# 4              {"name":null,"title":null,"url":null}                     True
#
#                            job_description_formatted  \
# 0  <section class="show-more-less-html" data-max-...
# 1  <section class="show-more-less-html" data-max-...
# 2  <section class="show-more-less-html" data-max-...
# 3  <section class="show-more-less-html" data-max-...
# 4  <section class="show-more-less-html" data-max-...
#
#                                          base_salary
# 0  {"currency":null,"max_amount":null,"min_amount...
# 1  {"currency":null,"max_amount":null,"min_amount...
# 2  {"currency":null,"max_amount":null,"min_amount...
# 3  {"currency":"CA$","max_amount":60,"min_amount"...
# 4  {"currency":null,"max_amount":null,"min_amount...
#
# [5 rows x 25 columns]
#
# Indeed Data:
#               jobid            company_name          date_posted_parsed  \
# 0  9637227804139a43           Memorial Care  "2025-01-21T14:20:02.000Z"
# 1  62b3047904eb4bcf  Fieldpiece Instruments  "2025-01-22T18:41:06.004Z"
# 2  e67ac9867cd1117d                Best Buy  "2025-01-22T18:07:16.942Z"
# 3  e9521d0b67b89857           Nordstrom Inc  "2025-01-22T18:07:16.300Z"
# 4  3b2ffa6e6daf278f     CommonSpirit Health  "2025-01-21T13:54:51.000Z"
#
#                                   job_title  \
# 0            Program Coord, Professionalism
# 1                    Recruiting Coordinator
# 2                Retail Warehouse Associate
# 3  Maintenance Technician 2 - Topanga Plaza
# 4                       HR Business Partner
#
#                                     description_text  \
# 0  Title: Coord, Professionalism Program\n    Loc...
# 1  Fieldpiece is hiring an organized and proactiv...
# 2  As a Retail Warehouse Associate, you’ll be par...
# 3  Job Description  JOB SUMMARY The Maintenance T...
# 4  Requisition ID 2024-385471\n          Employme...
#
#                                             benefits   job_type  \
# 0                               ["Health insurance"]  Full-time
# 1  ["401(k) 4% Match","401(k) matching","Employee...  Full-time
# 2                              ["Employee discount"]  Part-time
# 3  ["Dental insurance","Disability insurance","Em...  Full-time
# 4  ["401(k)","403(b)","Dental insurance","Health ...  Full-time
#
#                                          location         salary_formatted  \
# 0                            Long Beach, CA 90806  $41.87 - $60.73 an hour
# 1      1636 West Collins Avenue, Orange, CA 92867        $24 - $33 an hour
# 2   3410 Alpine Avenue NW, Grand Rapids, MI 49544  $15.00 - $17.88 an hour
# 3                               Thousand Oaks, CA  $23.75 - $41.25 an hour
# 4  1401 SOUTH GRAND AVENUE, Los Angeles, CA 90015  $35.13 - $50.94 an hour
#
#    company_rating  company_reviews_count country  date_posted  \
# 0             3.8                    321      US    1 day ago
# 1             3.2                      6      US  Just posted
# 2             3.8                  38563      US  Just posted
# 3             3.8                  17686      US  Just posted
# 4             3.6                   2242      US    1 day ago
#
#                                          description  \
# 0     Title: Coord, Professionalism Program\n    ...
# 1   Fieldpiece is hiring an organized and proacti...
# 2     As a Retail Warehouse Associate, you’ll be ...
# 3   Job Description  JOB SUMMARY The Maintenance ...
# 4            Requisition ID 2024-385471\n        ...
#
#                                         company_link                  domain  \
# 0  https://www.indeed.com/cmp/Memorialcare?campai...  https://www.indeed.com
# 1  https://www.indeed.com/cmp/Fieldpiece-Instrume...  https://www.indeed.com
# 2  https://www.indeed.com/cmp/Best-Buy?campaignid...  https://www.indeed.com
# 3  https://www.indeed.com/cmp/Nordstrom?campaigni...  https://www.indeed.com
# 4  https://www.indeed.com/cmp/Commonspirit-Health...  https://www.indeed.com
#
#                                           apply_link  \
# 0  https://www.indeed.com/rc/clk?jk=9637227804139...
# 1  https://www.indeed.com/rc/clk?jk=62b3047904eb4...
# 2  https://www.indeed.com/viewjob?viewtype=embedd...
# 3  https://www.indeed.com/viewjob?viewtype=embedd...
# 4  https://www.indeed.com/rc/clk?jk=3b2ffa6e6daf2...
#
#                                                  url  is_expired  \
# 0  https://www.indeed.com/rc/clk?jk=9637227804139...       False
# 1  https://www.indeed.com/rc/clk?jk=62b3047904eb4...       False
# 2  https://www.indeed.com/viewjob?viewtype=embedd...       False
# 3  https://www.indeed.com/viewjob?viewtype=embedd...       False
# 4  https://www.indeed.com/rc/clk?jk=3b2ffa6e6daf2...       False
#
#                  timestamp
# 0  2025-01-22 00:00:00.000
# 1  2025-01-22 00:00:00.000
# 2  2025-01-22 00:00:00.000
# 3  2025-01-22 00:00:00.000
# 4  2025-01-22 00:00:00.000
#
# GlassDoor Data:
#                                                  url     company_url_overview  \
# 0  https://www.glassdoor.com/partner/jobListing.h...  https://goo.gle/4ehVuXi
# 1  https://www.glassdoor.com/partner/jobListing.h...  https://goo.gle/4ehVuXi
# 2  https://www.glassdoor.com/partner/jobListing.h...  https://goo.gle/4ehVuXi
# 3  https://www.glassdoor.com/partner/jobListing.h...  https://goo.gle/4ehVuXi
# 4  https://www.glassdoor.com/partner/jobListing.h...  https://goo.gle/4ehVuXi
#
#   company_name  company_rating  \
# 0       Google             4.3
# 1       Google             4.3
# 2       Google             4.3
# 3       Google             4.3
# 4       Google             4.3
#
#                                            job_title       job_location  \
# 0         Facilities Manager, Data Center Operations     New Albany, OH
# 1                        Data Engineer, Go-to-Market  San Francisco, CA
# 2            Legal Specialist, Employment Litigation         Austin, TX
# 3  Customer Engineer II, Infrastructure Moderniza...      Charlotte, NC
# 4         Facilities Manager, Data Center Operations     New Albany, OH
#
#                                         job_overview company_headquarters  \
# 0  Minimum qualifications:\n\nBachelor's degree o...    Mountain View, CA
# 1  The application window will be open until at l...    Mountain View, CA
# 2  Minimum qualifications:\n\nBachelor's degree o...    Mountain View, CA
# 3  Note: Googleâ€™s hybrid workplace includes rem...    Mountain View, CA
# 4  Minimum qualifications:\n\nBachelor's degree o...    Mountain View, CA
#
#    company_founded_year         company_industry  ... company_id  \
# 0                1998.0  Internet & Web Services  ...       9079
# 1                1998.0  Internet & Web Services  ...       9079
# 2                1998.0  Internet & Web Services  ...       9079
# 3                1998.0  Internet & Web Services  ...       9079
# 4                1998.0  Internet & Web Services  ...       9079
#
#                                 job_application_link          company_website  \
# 0  https://www.glassdoor.com/partner/jobListing.h...  https://goo.gle/4ehVuXi
# 1  https://www.glassdoor.com/partner/jobListing.h...  https://goo.gle/4ehVuXi
# 2  https://www.glassdoor.com/partner/jobListing.h...  https://goo.gle/4ehVuXi
# 3  https://www.glassdoor.com/partner/jobListing.h...  https://goo.gle/4ehVuXi
# 4  https://www.glassdoor.com/partner/jobListing.h...  https://goo.gle/4ehVuXi
#
#   pay_range_glassdoor_est  pay_median_glassdoor  \
# 0                     NaN                   NaN
# 1                     NaN                   NaN
# 2                     NaN                   NaN
# 3                     NaN                   NaN
# 4                     NaN                   NaN
#
#    pay_range_employer_est__DUPLICATE__DUPLICATE pay_median_employer  \
# 0                                           NaN                 NaN
# 1                                           NaN                 NaN
# 2                                           NaN                 NaN
# 3                                           NaN                 NaN
# 4                                           NaN                 NaN
#
#    pay_range_currency  pay_type  discovery_input
# 0                 USD       NaN               {}
# 1                 USD       NaN               {}
# 2                 USD       NaN               {}
# 3                 USD       NaN               {}
# 4                 USD       NaN               {}
#
# [5 rows x 38 columns]

# %% [markdown]
# # Merging Indeed and LinkedIn Datasets

# %%
# Rename columns in Indeed set to match the LinkedIn
indeed_df = indeed_df.rename(columns={
    'location': 'job_location',
    'description_text': 'job_summary',
    'job_type': 'job_employment_type'
})

# Select relevant columns in sets
linkedin_df = linkedin_df[['job_title', 'company_name', 'job_location', 'job_summary', 'job_employment_type']]
indeed_df = indeed_df[['job_title', 'company_name', 'job_location', 'job_summary', 'job_employment_type']]

# Concatenate sets
merged_df = pd.concat([linkedin_df, indeed_df], ignore_index=True)

# Check result
print(merged_df.head())  # Display the first few rows of the merged set
print(f"\nTotal rows after merge: {len(merged_df)}")
# Out:
#                                  job_title  \
# 0  Software Developer - Driver and Vehicle
# 1                            API Developer
# 2                           .Net Developer
# 3                         Power BI Analyst
# 4        Scala Software Engineer - Backend
#
#                           company_name              job_location  \
# 0  Canadian Bank Note Company, Limited   Ottawa, Ontario, Canada
# 1                          Venngo Inc.  Toronto, Ontario, Canada
# 2                            BLAZESOFT  Vaughan, Ontario, Canada
# 3          Alquemy Search & Consulting  Calgary, Alberta, Canada
# 4                               Avetta                    Canada
#
#                                          job_summary job_employment_type
# 0  Description Internal Job Title : Software Deve...           Full-time
# 1  Who we are At Venngo, we provide premium disco...           Full-time
# 2  Join our dynamic and innovative gaming company...           Full-time
# 3  Power BI Analyst 12 month contract, potential ...            Contract
# 4  Avetta is Hiring a Scala Software Engineer - B...           Full-time
#
# Total rows after merge: 2000

# %% [markdown]
# # Adding In GlassDoor Dataset

# %%
# Rename columns in Glassdoor set to match
glassdoor_df = glassdoor_df.rename(columns={
    'job_overview': 'job_summary',
    'pay_type': 'job_employment_type'
})

# Select relevant columns in Glassdoor set
glassdoor_df = glassdoor_df[['job_title', 'company_name', 'job_location', 'job_summary', 'job_employment_type']]

# Concatenate Glassdoor set with existing merged set
final_merged_df = pd.concat([merged_df, glassdoor_df], ignore_index=True)

# Check result
print(final_merged_df.head())  # Display the first few rows of merged set
print(f"\nTotal rows after adding Glassdoor: {len(final_merged_df)}")
# Out:
#                                  job_title  \
# 0  Software Developer - Driver and Vehicle
# 1                            API Developer
# 2                           .Net Developer
# 3                         Power BI Analyst
# 4        Scala Software Engineer - Backend
#
#                           company_name              job_location  \
# 0  Canadian Bank Note Company, Limited   Ottawa, Ontario, Canada
# 1                          Venngo Inc.  Toronto, Ontario, Canada
# 2                            BLAZESOFT  Vaughan, Ontario, Canada
# 3          Alquemy Search & Consulting  Calgary, Alberta, Canada
# 4                               Avetta                    Canada
#
#                                          job_summary job_employment_type
# 0  Description Internal Job Title : Software Deve...           Full-time
# 1  Who we are At Venngo, we provide premium disco...           Full-time
# 2  Join our dynamic and innovative gaming company...           Full-time
# 3  Power BI Analyst 12 month contract, potential ...            Contract
# 4  Avetta is Hiring a Scala Software Engineer - B...           Full-time
#
# Total rows after adding Glassdoor: 3000

# %% [markdown]
# # Preliminary Visualizations

# %%
# Begin graph
sns.set_theme(style="whitegrid")

# Counts of each job type
employment_type_counts = final_merged_df['job_employment_type'].value_counts()

# Plot bar chart
plt.figure(figsize=(15, 10))
sns.barplot(x=employment_type_counts.index, y=employment_type_counts.values, palette="Blues_r")

# Title and labels
plt.title("Distribution of Job Employment Types", fontsize=13)
plt.xlabel("Employment Type", fontsize=14)
plt.ylabel("Count", fontsize=14)
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-6-616832c61831>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=employment_type_counts.index, y=employment_type_counts.values, palette="Blues_r")

# %%
# Make summaries lowercase for consistent search
final_merged_df['job_summary'] = final_merged_df['job_summary'].astype(str).str.lower()

# Keyword search
keywords = ['developer', 'analyst', 'engineer', 'scientist']

# Count num of each keyword in summaries
keyword_counts = {keyword.capitalize(): final_merged_df['job_summary'].str.contains(keyword).sum() for keyword in keywords}

# Plot pie chart
plt.figure(figsize=(8, 8))
plt.pie(keyword_counts.values(), labels=keyword_counts.keys(), autopct='%1.1f%%', colors=sns.color_palette("pastel"),
        startangle=140)

# Titles
plt.title("Proportion of Jobs Containing Key Terms in Summaries", fontsize=14)
plt.show()

# %%
final_merged_df.columns
# Out:
# Index(['job_title', 'company_name', 'job_location', 'job_summary',
#        'job_employment_type'],
#       dtype='object')

# %%
final_merged_df.head()
# Out:
#                                  job_title  \
# 0  Software Developer - Driver and Vehicle
# 1                            API Developer
# 2                           .Net Developer
# 3                         Power BI Analyst
# 4        Scala Software Engineer - Backend
#
#                           company_name              job_location  \
# 0  Canadian Bank Note Company, Limited   Ottawa, Ontario, Canada
# 1                          Venngo Inc.  Toronto, Ontario, Canada
# 2                            BLAZESOFT  Vaughan, Ontario, Canada
# 3          Alquemy Search & Consulting  Calgary, Alberta, Canada
# 4                               Avetta                    Canada
#
#                                          job_summary job_employment_type
# 0  description internal job title : software deve...           Full-time
# 1  who we are at venngo, we provide premium disco...           Full-time
# 2  join our dynamic and innovative gaming company...           Full-time
# 3  power bi analyst 12 month contract, potential ...            Contract
# 4  avetta is hiring a scala software engineer - b...           Full-time

# %%
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer

# Vectorize the job summaries
vectorizer = CountVectorizer(stop_words='english')
X = vectorizer.fit_transform(final_merged_df['job_summary'].dropna())

# Sum word frequencies and get the top 10 most common keywords
word_counts = X.sum(axis=0).A1
vocab = vectorizer.get_feature_names_out()
word_freq = dict(zip(vocab, word_counts))
top_keywords = Counter(word_freq).most_common(10)

# Plot the top 10 keywords
keywords, freq = zip(*top_keywords)
plt.barh(keywords, freq)
plt.xlabel('Frequency')
plt.title('Top 10 Keywords in Job Summaries')
plt.show()

# %%
location_counts = final_merged_df['job_location'].value_counts()

# Plot the distribution
plt.figure(figsize=(10, 6))
location_counts.head(20).plot(kind='barh', color='skyblue')
plt.title('Top 20 Job Locations')
plt.xlabel('Number of Job Postings')
plt.ylabel('Location')
plt.show()
